# %% [markdown]
# # Ansatz visualization

# %%
from example.ansatz import *

# %%
reps = 1
n_qubits = 4

# %% [markdown]
# ## 1. Hardware-efficient ansatz, Chain

# %%
ansatz = he_chain_ansatz(reps=reps, n_qubits=n_qubits)
ansatz.draw("mpl")

# %% [markdown]
# ## 2. Hardware-efficient ansatz, Complete

# %%
ansatz = he_complete_ansatz(reps=reps, n_qubits=n_qubits)
ansatz.draw("mpl")

# %% [markdown]
# ## 3. Hardware-efficient ansatz, Ladder

# %%
ansatz = he_ladder_ansatz(reps=reps, n_qubits=n_qubits)
ansatz.draw("mpl")

# %% [markdown]
# ## 4. Hardware-efficient ansatz, Cross-Ladder

# %%
ansatz = he_cross_ladder_ansatz(reps=reps, n_qubits=n_qubits)
ansatz.draw("mpl")

# %% [markdown]
# ## 5. 1D brick-block ansatz, Chain

# %%
ansatz = bb_chain_ansatz(reps=reps, n_qubits=n_qubits)
ansatz.draw("mpl")

# %% [markdown]
# ## 6. 1D brick-block ansatz, Stair

# %%
ansatz = bb_stair_ansatz(reps=reps, n_qubits=n_qubits)
ansatz.draw("mpl")

# %% [markdown]
# ## 7. 1D brick-block ansatz, Complete

# %%
ansatz = bb_complete_ansatz(reps=reps, n_qubits=n_qubits)
ansatz.draw("mpl")

# %% [markdown]
# ## 8. 1D brick-block ansatz, Ladder

# %%
ansatz = bb_ladder_ansatz(reps=reps, n_qubits=n_qubits)
ansatz.draw("mpl")

# %% [markdown]
# ## 9. 1D brick-block ansatz, Cross-Ladder

# %%
ansatz = bb_cross_ladder_ansatz(reps=reps, n_qubits=n_qubits)
ansatz.draw("mpl")
